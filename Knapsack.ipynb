# %%
# %load_ext autoreload
# %autoreload 2

# %%
import mlrose
import numpy as np
import matplotlib.pyplot as plt
from time import perf_counter as pc
import itertools
import pandas as pd
import copy
from sklearn.externals import joblib

from utilities_hw2 import plot_results

# %% [markdown]
# # Knapsack

# %%
iters = 5 # number of iterations for each setting in grid search

results = {}    

np.random.seed(2)

maxWeight = 0.65

n_items = [10, 20, 30, 40, 50, 75, 100]
# Initialize backpack parameters here so all algo's use the same problems
weights = {}
values = {}
for n_item in n_items:
    weights[n_item] = np.random.rand(n_item)
    values[n_item] = np.random.rand(n_item)


problem = mlrose.DiscreteOpt

algorithms = {
    'MIMIC': {
        'algorithm': mlrose.mimic,
        'param_grid_algorithm': {'return_statistics': True, 'pop_size': ['2*problem_length'], 'keep_pct': [0.2], 'max_attempts': [15], 'max_iters': 1000},
    },
    'Hill Climbing': {
        'algorithm': mlrose.hill_climb,
        'param_grid_algorithm': {'return_statistics': True, 'restarts': 5},
    },
#     'Hill Climbing (sample)': {
#         'algorithm': mlrose.random_hill_climb,
#         'param_grid_algorithm': {'return_statistics': True, 'restarts': 5, 'max_attempts': 20},
#     },
    'Simulated Annealing': {
        'algorithm': mlrose.simulated_annealing,
        'param_grid_algorithm': {'return_statistics': True, 'max_attempts': 100},
    },
    'Genetic Algorithm': {
        'algorithm': mlrose.genetic_alg,
        'param_grid_algorithm': {'return_statistics': True, 'elite': 0.3, 'pop_size': ['5*problem_length'], 'mutation_prob': 0.1, 'max_attempts': 10},
    },
}

# for k, d in algorithms.items():
#     d['problem'] = problem
#     d['param_grid_problem'] = param_grid_problem

for algo_name, settings in algorithms.items():
    results[algo_name] = []
    for n_item in n_items:
        fitness_fn = mlrose.Knapsack(weights[n_item], values[n_item], maxWeight)

        param_grid_problem = {'fitness_fn': fitness_fn,
                              'max_val': 2,
                              'length': n_item, 
                             }
        thisSettings = copy.deepcopy(settings.copy())
        thisSettings['problem'] = problem
        thisSettings['param_grid_problem'] = param_grid_problem
    
        print(f"Looping for {algo_name}, n_item={n_item}")
        gs = mlrose.GridSearch(algorithm=thisSettings['algorithm'], param_grid_algorithm=thisSettings['param_grid_algorithm'], 
                               problem=thisSettings['problem'], param_grid_problem=thisSettings['param_grid_problem'], iters=iters)
        gs.evaluate()
        this_df = pd.DataFrame(gs.results)
        results[algo_name].extend(gs.results)
# Out:
# Looping for MIMIC, n_item=10
# Running case 1/1: iteration 0
# MIMIC finished after using 15/15 attempts, 17/1000, iters
# Running case 1/1: iteration 1
# MIMIC finished after using 15/15 attempts, 16/1000, iters
# Running case 1/1: iteration 2
# MIMIC finished after using 15/15 attempts, 16/1000, iters
# Running case 1/1: iteration 3
# MIMIC finished after using 15/15 attempts, 16/1000, iters
# Running case 1/1: iteration 4
# MIMIC finished after using 15/15 attempts, 16/1000, iters
# Looping for MIMIC, n_item=20
# Running case 1/1: iteration 0
# MIMIC finished after using 15/15 attempts, 17/1000, iters
# Running case 1/1: iteration 1
# MIMIC finished after using 15/15 attempts, 18/1000, iters
# Running case 1/1: iteration 2
# MIMIC finished after using 15/15 attempts, 16/1000, iters
# Running case 1/1: iteration 3
# MIMIC finished after using 15/15 attempts, 17/1000, iters
# Running case 1/1: iteration 4
# MIMIC finished after using 15/15 attempts, 19/1000, iters
# Looping for MIMIC, n_item=30
# Running case 1/1: iteration 0
# MIMIC finished after using 15/15 attempts, 16/1000, iters
# Running case 1/1: iteration 1
# MIMIC finished after using 15/15 attempts, 18/1000, iters
# Running case 1/1: iteration 2
# MIMIC finished after using 15/15 attempts, 19/1000, iters
# Running case 1/1: iteration 3
# MIMIC finished after using 15/15 attempts, 19/1000, iters
# Running case 1/1: iteration 4
# MIMIC finished after using 15/15 attempts, 19/1000, iters
# Looping for MIMIC, n_item=40
# Running case 1/1: iteration 0
# MIMIC finished after using 15/15 attempts, 22/1000, iters
# Running case 1/1: iteration 1
# MIMIC finished after using 15/15 attempts, 20/1000, iters
# Running case 1/1: iteration 2
# MIMIC finished after using 15/15 attempts, 19/1000, iters
# Running case 1/1: iteration 3
# MIMIC finished after using 15/15 attempts, 22/1000, iters
# Running case 1/1: iteration 4
# MIMIC finished after using 15/15 attempts, 21/1000, iters
# Looping for MIMIC, n_item=50
# Running case 1/1: iteration 0
# MIMIC finished after using 15/15 attempts, 22/1000, iters
# Running case 1/1: iteration 1
# MIMIC finished after using 15/15 attempts, 26/1000, iters
# Running case 1/1: iteration 2
# MIMIC finished after using 15/15 attempts, 21/1000, iters
# Running case 1/1: iteration 3
# MIMIC finished after using 15/15 attempts, 21/1000, iters
# Running case 1/1: iteration 4
# MIMIC finished after using 15/15 attempts, 22/1000, iters
# Looping for MIMIC, n_item=75
# Running case 1/1: iteration 0
# MIMIC finished after using 15/15 attempts, 28/1000, iters
# Running case 1/1: iteration 1
# MIMIC finished after using 15/15 attempts, 25/1000, iters
# Running case 1/1: iteration 2
# MIMIC finished after using 15/15 attempts, 24/1000, iters
# Running case 1/1: iteration 3
# MIMIC finished after using 15/15 attempts, 27/1000, iters
# Running case 1/1: iteration 4
# MIMIC finished after using 15/15 attempts, 25/1000, iters
# Looping for MIMIC, n_item=100
# Running case 1/1: iteration 0
# MIMIC finished after using 15/15 attempts, 27/1000, iters
# Running case 1/1: iteration 1
# MIMIC finished after using 15/15 attempts, 31/1000, iters
# Running case 1/1: iteration 2
# MIMIC finished after using 15/15 attempts, 28/1000, iters
# Running case 1/1: iteration 3
# MIMIC finished after using 15/15 attempts, 28/1000, iters
# Running case 1/1: iteration 4
# MIMIC finished after using 15/15 attempts, 28/1000, iters
# Looping for Hill Climbing, n_item=10
# Running case 1/1: iteration 0
# Running case 1/1: iteration 1
# Running case 1/1: iteration 2
# Running case 1/1: iteration 3
# Running case 1/1: iteration 4
# Looping for Hill Climbing, n_item=20
# Running case 1/1: iteration 0
# Running case 1/1: iteration 1
# Running case 1/1: iteration 2
# Running case 1/1: iteration 3
# Running case 1/1: iteration 4
# Looping for Hill Climbing, n_item=30
# Running case 1/1: iteration 0
# Running case 1/1: iteration 1
# Running case 1/1: iteration 2
# Running case 1/1: iteration 3
# Running case 1/1: iteration 4
# Looping for Hill Climbing, n_item=40
# Running case 1/1: iteration 0
# Running case 1/1: iteration 1
# Running case 1/1: iteration 2
# Running case 1/1: iteration 3
# Running case 1/1: iteration 4
# Looping for Hill Climbing, n_item=50
# Running case 1/1: iteration 0
# Running case 1/1: iteration 1
# Running case 1/1: iteration 2
# Running case 1/1: iteration 3
# Running case 1/1: iteration 4
# Looping for Hill Climbing, n_item=75
# Running case 1/1: iteration 0
# Running case 1/1: iteration 1
# Running case 1/1: iteration 2
# Running case 1/1: iteration 3
# Running case 1/1: iteration 4
# Looping for Hill Climbing, n_item=100
# Running case 1/1: iteration 0
# Running case 1/1: iteration 1
# Running case 1/1: iteration 2
# Running case 1/1: iteration 3
# Running case 1/1: iteration 4
# Looping for Simulated Annealing, n_item=10
# Running case 1/1: iteration 0
# Search ended with attempts>max_attempts (100>100).  Iters=373
# Running case 1/1: iteration 1
# Search ended with attempts>max_attempts (100>100).  Iters=382
# Running case 1/1: iteration 2
# Search ended with attempts>max_attempts (100>100).  Iters=425
# Running case 1/1: iteration 3
# Search ended with attempts>max_attempts (100>100).  Iters=381
# Running case 1/1: iteration 4
# Search ended with attempts>max_attempts (100>100).  Iters=387
# Looping for Simulated Annealing, n_item=20
# Running case 1/1: iteration 0
# Search ended with attempts>max_attempts (100>100).  Iters=347
# Running case 1/1: iteration 1
# Search ended with attempts>max_attempts (100>100).  Iters=344
# Running case 1/1: iteration 2
# Search ended with attempts>max_attempts (100>100).  Iters=303
# Running case 1/1: iteration 3
# Search ended with attempts>max_attempts (100>100).  Iters=392
# Running case 1/1: iteration 4
# Search ended with attempts>max_attempts (100>100).  Iters=384
# Looping for Simulated Annealing, n_item=30
# Running case 1/1: iteration 0
# Search ended with attempts>max_attempts (100>100).  Iters=352
# Running case 1/1: iteration 1
# Search ended with attempts>max_attempts (100>100).  Iters=321
# Running case 1/1: iteration 2
# Search ended with attempts>max_attempts (100>100).  Iters=375
# Running case 1/1: iteration 3
# Search ended with attempts>max_attempts (100>100).  Iters=427
# Running case 1/1: iteration 4
# Search ended with attempts>max_attempts (100>100).  Iters=310
# Looping for Simulated Annealing, n_item=40
# Running case 1/1: iteration 0
# Search ended with attempts>max_attempts (100>100).  Iters=400
# Running case 1/1: iteration 1
# Search ended with attempts>max_attempts (100>100).  Iters=295
# Running case 1/1: iteration 2
# Search ended with attempts>max_attempts (100>100).  Iters=512
# Running case 1/1: iteration 3
# Search ended with attempts>max_attempts (100>100).  Iters=323
# Running case 1/1: iteration 4
# Search ended with attempts>max_attempts (100>100).  Iters=451
# Looping for Simulated Annealing, n_item=50
# Running case 1/1: iteration 0
# Search ended with attempts>max_attempts (100>100).  Iters=360
# Running case 1/1: iteration 1
# Search ended with attempts>max_attempts (100>100).  Iters=413
# Running case 1/1: iteration 2
# Search ended with attempts>max_attempts (100>100).  Iters=438
# Running case 1/1: iteration 3
# Search ended with attempts>max_attempts (100>100).  Iters=338
# Running case 1/1: iteration 4
# Search ended with attempts>max_attempts (100>100).  Iters=439
# Looping for Simulated Annealing, n_item=75
# Running case 1/1: iteration 0
# Search ended with attempts>max_attempts (100>100).  Iters=428
# Running case 1/1: iteration 1
# Search ended with attempts>max_attempts (100>100).  Iters=387
# Running case 1/1: iteration 2
# Search ended with attempts>max_attempts (100>100).  Iters=434
# Running case 1/1: iteration 3
# Search ended with attempts>max_attempts (100>100).  Iters=452
# Running case 1/1: iteration 4
# Search ended with attempts>max_attempts (100>100).  Iters=475
# Looping for Simulated Annealing, n_item=100
# Running case 1/1: iteration 0
# Search ended with attempts>max_attempts (100>100).  Iters=376
# Running case 1/1: iteration 1
# Search ended with attempts>max_attempts (100>100).  Iters=413
# Running case 1/1: iteration 2
# Search ended with attempts>max_attempts (100>100).  Iters=426
# Running case 1/1: iteration 3
# Search ended with attempts>max_attempts (100>100).  Iters=534
# Running case 1/1: iteration 4
# Search ended with attempts>max_attempts (100>100).  Iters=389
# Looping for Genetic Algorithm, n_item=10
# Running case 1/1: iteration 0
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=12
# Running case 1/1: iteration 1
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=20
# Running case 1/1: iteration 2
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=21
# Running case 1/1: iteration 3
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=20
# Running case 1/1: iteration 4
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=18
# Looping for Genetic Algorithm, n_item=20
# Running case 1/1: iteration 0
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=19
# Running case 1/1: iteration 1
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=38
# Running case 1/1: iteration 2
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=19
# Running case 1/1: iteration 3
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=34
# Running case 1/1: iteration 4
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=43
# Looping for Genetic Algorithm, n_item=30
# Running case 1/1: iteration 0
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=27
# Running case 1/1: iteration 1
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=36
# Running case 1/1: iteration 2
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=31
# Running case 1/1: iteration 3
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=37
# Running case 1/1: iteration 4
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=15
# Looping for Genetic Algorithm, n_item=40
# Running case 1/1: iteration 0
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=62
# Running case 1/1: iteration 1
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=32
# Running case 1/1: iteration 2
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=24
# Running case 1/1: iteration 3
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=22
# Running case 1/1: iteration 4
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=43
# Looping for Genetic Algorithm, n_item=50
# Running case 1/1: iteration 0
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=59
# Running case 1/1: iteration 1
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=36
# Running case 1/1: iteration 2
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=20
# Running case 1/1: iteration 3
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=29
# Running case 1/1: iteration 4
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=40
# Looping for Genetic Algorithm, n_item=75
# Running case 1/1: iteration 0
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=51
# Running case 1/1: iteration 1
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=29
# Running case 1/1: iteration 2
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=27
# Running case 1/1: iteration 3
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=41
# Running case 1/1: iteration 4
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=19
# Looping for Genetic Algorithm, n_item=100
# Running case 1/1: iteration 0
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=60
# Running case 1/1: iteration 1
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=43
# Running case 1/1: iteration 2
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=26
# Running case 1/1: iteration 3
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=20
# Running case 1/1: iteration 4
# running with elite = 0.3
# Search ended with attempts>max_attempts (10>10).  Iters=80

# %%
fname = 'knapsack_results.pkl'
joblib.dump(results, fname)
# results2 = joblib.load(fname)
# Out:
# ['knapsack_results.pkl']

# %%
results_df = {k: pd.DataFrame(r) for k, r in results.items()}
# for k, df in results_df.items():
#     print(df)

# %%
plot_results(results_df, savefig='knapsack')
